# %%
x = []
x.append(18)
x.append('Huế')
y = [12, 45, -1, -0.56, "abc"]
x.extend(y)
print(x)
print(x[0])
print(x[-1])
print(x[:5])
print(x[3:])
# Out:
# [18, 'Huế', 12, 45, -1, -0.56, 'abc']
# 18
# abc
# [18, 'Huế', 12, 45, -1]
# [45, -1, -0.56, 'abc']
